# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("resources/wine1.csv")

# %%
df.head()
# Out:
#    A      B     C     D     E    F     G     H     I     J     K     L     M  \
# 0  1  14.23  1.71  2.43  15.6  127  2.80  3.06  0.28  2.29  5.64  1.04  3.92
# 1  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 2  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 3  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 4  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
#
#       N
# 0  1065
# 1  1050
# 2  1185
# 3  1480
# 4   735

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

km = KMeans(n_clusters=3, max_iter=400,verbose=True,tol=0.2)
pred = km.fit_predict(df[['B','C']])
plt.scatter(df['B'], df['C'],c=df['A'])
score = accuracy_score(df['A'], pred)
score
# Out:
# Initialization complete
# Iteration 0, inertia 116.43080000000005
# Iteration 1, inertia 95.92969746723858
# Converged at iteration 1: center shift 0.00594780023473791 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 174.17760000000004
# Iteration 1, inertia 144.80762144768588
# Converged at iteration 1: center shift 0.05467295694864506 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 121.79810000000002
# Iteration 1, inertia 96.24001149037008
# Converged at iteration 1: center shift 0.010736197391939662 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 129.31760000000008
# Iteration 1, inertia 98.50947900158808
# Converged at iteration 1: center shift 0.037583120827546695 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 141.44220000000007
# Iteration 1, inertia 98.74279504126625
# Converged at iteration 1: center shift 0.035753700481475616 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 135.659
# Iteration 1, inertia 99.24906862458405
# Converged at iteration 1: center shift 0.03997425330318739 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 122.73309999999995
# Iteration 1, inertia 98.76764168447369
# Converged at iteration 1: center shift 0.03520372278855609 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 107.62460000000004
# Converged at iteration 0: center shift 0.17688935199702976 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 164.59809999999996
# Iteration 1, inertia 145.350510378971
# Converged at iteration 1: center shift 0.048085529855036974 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 147.2424
# Iteration 1, inertia 99.4930527427358
# Converged at iteration 1: center shift 0.05262329182872437 within tolerance 0.1896363811387452.
# 0.34269662921348315

# %%
plt.scatter(df['B'], df['C'], c=pred)
plt.scatter(km.cluster_centers_[:,0] ,km.cluster_centers_[:,1], color='black')
